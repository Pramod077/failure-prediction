# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramod077/failure-prediction/blob/main/RAILING%20SYSTMS%20MTR%20MATERIAL%20TEST%20REPORTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create simple linear regression model
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

# %%
report = pd.read_excel('https://github.com/Pramod077/failure-prediction/blob/main/MTR.xlsx')
report.head()
# Out:
#   File "/tmp/ipython-input-1366299820.py", line 1
#     report = pd.read_excel(https://github.com/Pramod077/failure-prediction/blob/main/MTR.xlsx)
#                                 ^
# SyntaxError: invalid syntax
